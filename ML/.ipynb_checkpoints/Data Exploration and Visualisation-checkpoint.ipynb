# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df = pd.read_excel("../DataScraper/NBAScores.xlsx")
df.head()
# Out:
#    Unnamed: 0 Team     Match Up   Game Date W/L  MIN  PTS  FGM  FGA   FG%  \
# 0           0  MIA  MIA vs. ORL  04/09/2023   W  240  123   45   83  54.2
# 1           1  CLE  CLE vs. CHA  04/09/2023   L  240   95   35   89  39.3
# 2           2  CHA    CHA @ CLE  04/09/2023   W  240  106   37   81  45.7
# 3           3  WAS  WAS vs. HOU  04/09/2023   L  240  109   41   97  42.3
# 4           4  CHI  CHI vs. DET  04/09/2023   W  240  103   40   95  42.1
#
#    ...   FT%  OREB  DREB  REB  AST  STL  BLK  TOV  PF  +/-
# 0  ...  75.0     7    37   44   30   10    3   18  20   13
# 1  ...  93.8    11    33   44   27    9    5   16  24  -11
# 2  ...  86.7    10    39   49   23    8    5   19  14   11
# 3  ...  61.9    14    37   51   28   11    5   13  21   -5
# 4  ...  77.3    11    37   48   21   15    7    4  16   22
#
# [5 rows x 25 columns]

# %% [markdown]
# We will drop the first three columns and min and final points column as they arn't important. We will also transform the game date as year, since the specific date isn't important.

# %%
df.drop(columns=df.columns[0:3], axis=1,  inplace=True)
df.drop(columns=df.columns[2:4], axis=1,  inplace=True)
df.drop(columns=df.columns[-1], axis=1,  inplace=True)
df.head()
# Out:
#     Game Date W/L  FGM  FGA   FG%  3PM  3PA   3P%  FTM  FTA   FT%  OREB  DREB  \
# 0  04/09/2023   W   45   83  54.2   18   44  40.9   15   20  75.0     7    37
# 1  04/09/2023   L   35   89  39.3   10   37  27.0   15   16  93.8    11    33
# 2  04/09/2023   W   37   81  45.7    6   32  18.8   26   30  86.7    10    39
# 3  04/09/2023   L   41   97  42.3   14   45  31.1   13   21  61.9    14    37
# 4  04/09/2023   W   40   95  42.1    6   30  20.0   17   22  77.3    11    37
#
#    REB  AST  STL  BLK  TOV  PF
# 0   44   30   10    3   18  20
# 1   44   27    9    5   16  24
# 2   49   23    8    5   19  14
# 3   51   28   11    5   13  21
# 4   48   21   15    7    4  16

# %%
def strip_last_four(s):
    return s[-4:]

df['Game Date'] = df['Game Date'].apply(strip_last_four)
df = df.rename(columns={'Game Date': 'Year'})
df.head()
# Out:
#    Year W/L  FGM  FGA   FG%  3PM  3PA   3P%  FTM  FTA   FT%  OREB  DREB  REB  \
# 0  2023   W   45   83  54.2   18   44  40.9   15   20  75.0     7    37   44
# 1  2023   L   35   89  39.3   10   37  27.0   15   16  93.8    11    33   44
# 2  2023   W   37   81  45.7    6   32  18.8   26   30  86.7    10    39   49
# 3  2023   L   41   97  42.3   14   45  31.1   13   21  61.9    14    37   51
# 4  2023   W   40   95  42.1    6   30  20.0   17   22  77.3    11    37   48
#
#    AST  STL  BLK  TOV  PF
# 0   30   10    3   18  20
# 1   27    9    5   16  24
# 2   23    8    5   19  14
# 3   28   11    5   13  21
# 4   21   15    7    4  16

# %% [markdown]
# Seperate Wins and losses into seperate dataframes

# %%
df = df.rename(columns={'W/L': 'WinLoss', 'FG%': "FGpercent", '3P%':'3percent', 'FT%':'ftpercent'})
df['WinLoss'] = df['WinLoss'].replace({'W': 1, 'L': 0})
wins = df[df.WinLoss==1]
losses = df[df.WinLoss==0]
wins.head()
# Out:
#    Year  WinLoss  FGM  FGA  FGpercent  3PM  3PA  3percent  FTM  FTA  \
# 0  2023        1   45   83       54.2   18   44      40.9   15   20
# 2  2023        1   37   81       45.7    6   32      18.8   26   30
# 4  2023        1   40   95       42.1    6   30      20.0   17   22
# 7  2023        1   51  104       49.0   15   38      39.5   21   30
# 8  2023        1   53  101       52.5   14   32      43.8   14   19
#
#    ftpercent  OREB  DREB  REB  AST  STL  BLK  TOV  PF
# 0       75.0     7    37   44   30   10    3   18  20
# 2       86.7    10    39   49   23    8    5   19  14
# 4       77.3    11    37   48   21   15    7    4  16
# 7       70.0    13    56   69   31    2    3   12  13
# 8       73.7    13    37   50   31   10    5   13  23

# %%
def triStatPlots(attList):
    fig, plot = plt.subplots(3, 2, figsize=(20, 20))
    for i, stat in enumerate(attList):
        plot[i,0].scatter(stat[1], wins.WinLoss, label='wins', color='blue')
        plot[i,0].scatter(stat[0], losses.WinLoss, label='losses', color='red')
        plot[i,0].set_xlabel(stat[2])
        plot[i,0].set_ylabel('Win/Loss')
        plot[i,0].set_title('Win:Loss by ' +  stat[2])
        plot[i,1].boxplot([wins.FGA, losses.FGA], labels=['FGA For Wins', 'FGA For Losses'])
        plot[i,1].set_xlabel('Groups')
        plot[i,1].set_ylabel('Values')
        plot[i,1].set_title(stat[2] + ' win/loss')
    fig.tight_layout()

# %% [markdown]
# Field Goal Analysis

# %%
attList = [(losses.FGM, wins.FGM, 'Field Goals Made'), (losses.FGA, wins.FGA, 'Field Goals Attempted'), (losses.FGpercent, wins.FGpercent, 'Field Goal Percentage')]
triStatPlots(attList)

# %% [markdown]
# 3 Point Analysis
